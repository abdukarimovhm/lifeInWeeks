# %%
import matplotlib.pyplot as plt
import numpy as np

# Define the number of years and weeks
years = 100
weeks_per_year = 52

# Create the grid
fig, ax = plt.subplots(figsize=(20, 10))

# Set the limits
ax.set_xlim(0, weeks_per_year)
ax.set_ylim(years, 0)

# Set ticks for every 5 weeks on x-axis
ax.set_xticks(np.arange(0, weeks_per_year + 1, 5))

# Set ticks for every 5 years on y-axis
ax.set_yticks(np.arange(0, years + 1, 5))

# Draw horizontal lines for each week
for week in range(weeks_per_year):
    ax.axvline(x=week, color='gray', linestyle='--', linewidth=0.5)

# Draw horizontal lines for each year
for year in range(1, years):
    ax.axhline(y=year, color='gray', linestyle='-', linewidth=0.5)

# Draw gridlines
ax.grid(which='both', axis='both', linestyle='-', color='k', linewidth=0.5)

# Place x-axis labels on top
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Hide the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set labels
ax.set_xlabel('Week of the Year')
ax.set_ylabel('Year')

# Title
plt.title('Life in Weeks: 100 Years')

# Show the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import matplotlib.patches as mpatches

# Define the number of years and weeks per year
years = 100
weeks_per_year = 52

# Create the data and reshape it
data = np.arange(1, years * weeks_per_year + 1).reshape(years, weeks_per_year)

# Create discrete colormap
cmap = colors.ListedColormap([
    "#C8E6C9",  # Early Childhood
    "#FFCDD2",  # School Years
    "#F0F4C3",  # College
    "#BBDEFB",  # Career
    "#D1C4E9"   # Retirement
])

# Define the bounds
# Early Childhood: 0-7 years (0-364 weeks)
# School Years: 7-18 years (365-936 weeks)
# College: 18-22 years (937-1144 weeks)
# Career: 22-60 years (1145-3120 weeks)
# Retirement: 60-100 years (3121-5200 weeks)
bounds = [0, 365, 937, 1145, 3121, 5200]
norm = colors.BoundaryNorm(bounds, cmap.N)

fig, ax = plt.subplots(figsize=(15, 20))
extent = [0, weeks_per_year, years, 0]
im = ax.imshow(data, cmap=cmap, norm=norm, aspect='auto', extent=extent)

# Draw gridlines
ax.grid(which='both', axis='both', linestyle='-', color='k', linewidth=1)

# Set ticks for weeks on x-axis
ax.set_xticks(np.arange(0, weeks_per_year, 5))
ax.set_xticks(np.arange(0, weeks_per_year + 1, 1), minor=True)

# Set ticks for years on y-axis
ax.set_yticks(np.arange(0, years, 5))
ax.set_yticks(np.arange(0, years + 1, 1), minor=True)

# Place x-axis labels on top
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Hide the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set labels and title
ax.set_xlabel('Week of the Year')
ax.set_ylabel('Year')
plt.title('Life in Weeks: 100 Years')

# Create custom legend
legend_patches = [
    mpatches.Patch(color="#C8E6C9", label='Early Childhood (0-7 years)'),
    mpatches.Patch(color="#FFCDD2", label='School Years (7-18 years)'),
    mpatches.Patch(color="#F0F4C3", label='College (18-22 years)'),
    mpatches.Patch(color="#BBDEFB", label='Career (22-60 years)'),
    mpatches.Patch(color="#D1C4E9", label='Retirement (60-100 years)')
]

# Add the legend to the plot
ax.legend(handles=legend_patches, loc='center left', bbox_to_anchor=(-0.3, 1), fontsize='large')

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import matplotlib.patches as mpatches

# Define the number of years and weeks per year
years = 100
weeks_per_year = 52

# Create the data and reshape it
data = np.arange(1, years * weeks_per_year + 1).reshape(years, weeks_per_year)

# Create discrete colormap
cmap = colors.ListedColormap([
    "#C8E6C9",  # Early Childhood
    "#FFCDD2",  # School Years
    "#F0F4C3",  # College
    "#BBDEFB",  # Career
    "#D1C4E9"   # Retirement
])

# Define the bounds
# Early Childhood: 0-7 years (0-364 weeks)
# School Years: 7-18 years (365-936 weeks)
# College: 18-22 years (937-1144 weeks)
# Career: 22-60 years (1145-3120 weeks)
# Retirement: 60-100 years (3121-5200 weeks)
bounds = [0, 365, 936, 1145, 3121, 5200]
norm = colors.BoundaryNorm(bounds, cmap.N)

fig, ax = plt.subplots(figsize=(10, 15))
extent = [0, weeks_per_year, years, 0]
im = ax.imshow(data, cmap=cmap, norm=norm, aspect='auto', extent=extent)

# Draw gridlines
ax.grid(which='both', axis='both', linestyle='-', color='k', linewidth=1)

# Set ticks for weeks on x-axis
ax.set_xticks(np.arange(0, weeks_per_year, 5))
ax.set_xticks(np.arange(0, weeks_per_year + 1, 1), minor=True)

# Set ticks for years on y-axis
ax.set_yticks(np.arange(0, years, 5))
ax.set_yticks(np.arange(0, years + 1, 1), minor=True)

# Place x-axis labels on top
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Hide the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set labels and title
ax.set_xlabel('Week of the Year')
ax.set_ylabel('Year')
plt.title('Life in Weeks: 100 Years')

# Create custom legend
legend_patches = [
    mpatches.Patch(color="#C8E6C9", label='Early Childhood (0-7 years)'),
    mpatches.Patch(color="#FFCDD2", label='School Years (7-18 years)'),
    mpatches.Patch(color="#F0F4C3", label='College (18-22 years)'),
    mpatches.Patch(color="#BBDEFB", label='Career (22-60 years)'),
    mpatches.Patch(color="#D1C4E9", label='Retirement (60-100 years)')
]

# Add the legend to the plot, positioned to the left and outside the plot
ax.legend(handles=legend_patches, loc='center left', bbox_to_anchor=(-0.3, 1), fontsize='large')

# Annotate the 3744th week
week = 3700
year = week // weeks_per_year
week_in_year = week % weeks_per_year

def annotate_week(ax, week, text):
    year = week // weeks_per_year
    week_in_year = week % weeks_per_year

    # Calculate the center of the box for the given week
    center_x = week_in_year + 0.5
    center_y = year + 0.5

    # Force a draw of the figure to get the renderer
    fig.canvas.draw()

    # Create the main annotation box with the updated placement
    ax.annotate(
        text, 
        xy=(center_x, center_y), 
        xytext=(weeks_per_year + 1, center_y),  # Place the text outside the plot to the right
        textcoords='data',
        va='center', ha='left',
        bbox=dict(boxstyle='round', facecolor='white', edgecolor='black'),
        fontsize='large',
        arrowprops=dict(arrowstyle='-|>',edgecolor = 'red', facecolor='red'),
        annotation_clip=False
    )

# Annotate the 3744th week
annotate_week(ax, 3744, 'Expected death at week 3744 (age ~72 years)')
annotate_week(ax, 1446, 'Avarage marriage for men' )
annotate_week(ax, )
# Display the plot
plt.tight_layout()
plt.show()

# %%
annotate_week(ax, 1446, 'Avarage marriage for men' )

# Display the plot
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import matplotlib.patches as mpatches
import math

# Define the number of years and weeks per year
years = 90
weeks_per_year = 52

# Create the data and reshape it
data = np.arange(1, years * weeks_per_year + 1).reshape(years, weeks_per_year)

# Create discrete colormap

cmap = colors.ListedColormap([
    "#A5D6A7",  # Early Childhood
    "#FF8A80",  # School Years
    "#FFF59D",  # College
    "#90CAF9",  # Career
    "#CE93D8"   # Retirement
])


# Define the bounds
bounds = [0, 347, 937, 1145, 3121, 5200]
norm = colors.BoundaryNorm(bounds, cmap.N)

fig, ax = plt.subplots(figsize=(20, 12))
extent = [0, weeks_per_year, years, 0]
im = ax.imshow(data, cmap=cmap, norm=norm, aspect='auto', extent=extent)

im.format_cursor_data = lambda data: ""

# Draw gridlines
ax.grid(which='both', axis='both', linestyle='-', color='k', linewidth=0.27)

# Set ticks for weeks on x-axis
ax.set_xticks(np.arange(0, weeks_per_year, 5))
ax.set_xticks(np.arange(0, weeks_per_year + 1, 1), minor=True)

# Set ticks for years on y-axis
ax.set_yticks(np.arange(0, years, 5))
ax.set_yticks(np.arange(0, years + 1, 1), minor=True)

tick_label_size = 12  # Define your desired tick label size here
ax.tick_params(axis='both', which='major', labelsize=tick_label_size)
ax.tick_params(axis='both', which='minor', labelsize=tick_label_size * 0.8)

# Place x-axis labels on top
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Hide the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set labels and title
ax.set_xlabel('Haftalar')
ax.set_ylabel('Yillar')
plt.title('Hayot haftalarda: 90 yil')

# Create custom legend
legend_patches = [
    mpatches.Patch(color="#A5D6A7", label='Early Childhood (0-7 years)'),
    mpatches.Patch(color="#FF8A80", label='School Years (7-18 years)'),
    mpatches.Patch(color="#FFF59D", label='College (18-22 years)'),
    mpatches.Patch(color="#90CAF9", label='Career (22-60 years)'),
    mpatches.Patch(color="#CE93D8", label='Retirement (60-100 years)')
]

# Add the legend to the plot, positioned to the left and outside the plot
ax.legend(handles=legend_patches, loc='center left', bbox_to_anchor=(-0.3, 1), fontsize='large')

# Annotate the weeks
def annotate_week(ax, week, text, previous_annotations):
    year = week // weeks_per_year
    week_in_year = week % weeks_per_year

    # Calculate the center of the box for the given week
    center_x = week_in_year + 0.5
    center_y = year + 0.5

    # Calculate the offset for the annotation text to avoid overlap
    offset = 0
    for prev_center_y in previous_annotations:
        if abs(prev_center_y - center_y) < 2:  # If the y position is very close to previous
            offset += 10  # Adjust the offset as needed to avoid overlap

    xytext = (weeks_per_year + 2, center_y + offset)

    # Create the main annotation box with the updated placement
    ax.annotate(
        text, 
        xy=(center_x, center_y), 
        xytext=xytext,  # Adjusted xytext coordinates
        textcoords='data',
        va='center', ha='left',
        bbox=dict(boxstyle='round', facecolor='white', edgecolor='black'),
        fontsize='large',
        arrowprops=dict(arrowstyle='-|>', edgecolor='blue', facecolor='blue'),
        annotation_clip=False
    )

    # Append the current center_y to the list of previous annotations
    previous_annotations.append(center_y)

def calculate_week(year):
    # Calculate the total number of weeks
    total_weeks = weeks_per_year * year

    return int(total_weeks)

# Initial plot setup
previous_annotations = []
annotate_week(ax, 4004, "Ayollarning o'rtacha umr davomiyligi", previous_annotations)
annotate_week(ax, 3744, "Erkaklarning o'rtacha umr davomiyligi", previous_annotations)
annotate_week(ax, 1092, "Spirtli ichimliklar va tamaki mahsulotlar sotib olish mumkin bo'lgan hafta", previous_annotations)
annotate_week(ax, 936, "Avto ulovni qonuniy boshqarish mumkin bo'lgan hafta", previous_annotations)
annotate_week(ax, 1160, "Ayollarning o'rtacha turmush qurish yoshi", previous_annotations)
annotate_week(ax, 1378, "Erkaklarning o'rtacha turmush qurish yoshi", previous_annotations)


# Loop to prompt user for input
stop_loop = False
while not stop_loop:
    year_input = input("Enter the year (or type 'stop' to stop): ")
    
    if year_input.lower() == 'stop':
        stop_loop = True
        continue
    
    try:
        year = float(year_input)
        week_number = calculate_week(year)
    
        annotation_text = input("Enter the annotation text: ")

        # Annotate the user input
        annotate_week(ax, week_number, annotation_text, previous_annotations)
        
        # Display the updated plot
        plt.draw()
    except ValueError:
        print("Please enter a valid number for the year.")


integer_value = 19.63 # Replace with your desired integer value
rounded_down = math.floor(integer_value)
integer_week = ((integer_value - rounded_down) * 52)
rounded_week = math.ceil(integer_week)

# Iterate through each row up to the 24th row
for row in range(int(integer_value) + 1):
    # Adjust the y-coordinate to draw the line in the middle of each row
    y_coordinate = row + 0.5
    
    # If it's the 24th row, draw the line up to column 38
    if row == rounded_down:
        ax.hlines(y=y_coordinate, xmin=0, xmax=rounded_week, color='#737373', linewidth=4, linestyle='-')
    # For other rows, draw the line up to the last column
    else:
        ax.hlines(y=y_coordinate, xmin=0, xmax=weeks_per_year, color='#737373', linewidth=4, linestyle='-')

# Display the plot

print(rounded_week)
plt.tight_layout()
plt.show()
# Out:
# 33

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import matplotlib.patches as mpatches
import math
from datetime import datetime
import textwrap

# Define the number of years and weeks per year
years = 90
weeks_per_year = 52

# Create the data and reshape it
data = np.arange(1, years * weeks_per_year + 1).reshape(years, weeks_per_year)

# Create discrete colormap
cmap = colors.ListedColormap([
    "#A5D6A7",  # Early Childhood
    "#FF8A80",  # School Years
    "#FFF59D",  # College
    "#90CAF9",  # Career
    "#CE93D8"   # Retirement
])

# Define the bounds
bounds = [0, 347, 937, 1145, 3121, 5200]
norm = colors.BoundaryNorm(bounds, cmap.N)

fig, ax = plt.subplots(figsize=(20, 12))
extent = [0, weeks_per_year, years, 0]
im = ax.imshow(data, cmap=cmap, norm=norm, aspect='auto', extent=extent)

im.format_cursor_data = lambda data: ""

# Draw gridlines
ax.grid(which='both', axis='both', linestyle='-', color='k', linewidth=0.27)

# Set ticks for weeks on x-axis
ax.set_xticks(np.arange(0, weeks_per_year, 5))
ax.set_xticks(np.arange(0, weeks_per_year + 1, 1), minor=True)

# Set ticks for years on y-axis
ax.set_yticks(np.arange(0, years, 5))
ax.set_yticks(np.arange(0, years + 1, 1), minor=True)

tick_label_size = 12  # Define your desired tick label size here
ax.tick_params(axis='both', which='major', labelsize=tick_label_size)
ax.tick_params(axis='both', which='minor', labelsize=tick_label_size * 0.8)

# Place x-axis labels on top
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Hide the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set labels and title
ax.set_xlabel('Haftalar', fontsize = 24, color = '#800000')


ax.set_ylabel('Yillar', fontsize = 24, color = '#800000')
ax.yaxis.set_label_position('left')
ax.yaxis.set_label_coords(-0.05, 0.97)
plt.title('Hayot haftalarda: 90 yil', fontsize = 28, color = '#191970')

# Create custom legend
legend_patches = [
    mpatches.Patch(color="#A5D6A7", label='Bolalik (0-7 yosh)'),
    mpatches.Patch(color="#FF8A80", label='Maktab yillari (7-18 yosh)'),
    mpatches.Patch(color="#FFF59D", label='Oliy ta\'lim (18-22 yosh)'),
    mpatches.Patch(color="#90CAF9", label='Ish faoliyati (22-60 yosh)'),
    mpatches.Patch(color="#CE93D8", label='Nafaqa davri (60-100 yosh)')
]

# Add the legend to the plot, positioned to the lower left and outside the plot
# Add the legend to the plot, positioned to the top right and outside the plot
ax.legend(handles=legend_patches, loc='upper left', bbox_to_anchor=(1, 1), fontsize='xx-large')

# Annotate the weeks
def annotate_week(ax, week, text, previous_annotations):
    year = week // weeks_per_year
    week_in_year = week % weeks_per_year

    # Calculate the center of the box for the given week
    center_x = week_in_year + 0.5
    center_y = year + 0.5

    # Wrap text if it's too long
    wrapped_text = "\n".join(textwrap.wrap(text, width=30))

    # Calculate the offset for the annotation text to avoid overlap
    offset = 0
    for prev_center_y, prev_text in previous_annotations:
        if abs(prev_center_y - center_y) < 5:  # If the y position is very close to previous
            offset += 20  # Adjust the offset as needed to avoid overlap

    xytext = (-17, center_y + offset)

    # Create the main annotation box with the updated placement
    ax.annotate(
        wrapped_text, 
        xy=(center_x, center_y), 
        xytext=xytext,  # Adjusted xytext coordinates
        textcoords='data',
        va='center', ha='left',
        bbox=dict(boxstyle='round', facecolor='white', edgecolor='black'),
        fontsize=14,
        arrowprops=dict(arrowstyle='-|>', edgecolor='black', facecolor='black', shrinkA = 0, shrinkB = 5, connectionstyle ="arc3, rad = 0.1"),
        annotation_clip=False
    )

    # Append the current center_y and text length to the list of previous annotations
    previous_annotations.append((center_y + offset, wrapped_text))

def calculate_week(year):
    # Calculate the total number of weeks
    total_weeks = weeks_per_year * year

    return int(total_weeks)

def week_calculator(date_str):
    birth_date = datetime(1930, 1, 1)  # Assuming birth date is January 1, 1930
    target_date = datetime.strptime(date_str, "%d.%m.%Y")
    delta = target_date - birth_date
    return delta.days // 7  # Convert days to weeks

# Initial plot setup
previous_annotations = []
annotate_week(ax, 4004, "Ayollarning o'rtacha umr davomiyligi", previous_annotations)
annotate_week(ax, 3744, "Erkaklarning o'rtacha umr davomiyligi", previous_annotations)
annotate_week(ax, 1092, "Spirtli ichimliklar va tamaki mahsulotlar sotib olish mumkin bo'lgan hafta", previous_annotations)
annotate_week(ax, 936, "Avto ulovni qonuniy boshqarish mumkin bo'lgan hafta", previous_annotations)
annotate_week(ax, 1160, "Ayollarning o'rtacha turmush qurish yoshi", previous_annotations)
annotate_week(ax, 1378, "Erkaklarning o'rtacha turmush qurish yoshi", previous_annotations)

# Loop to prompt user for input
stop_loop = False
while not stop_loop:
    date_input = input("Enter the date (dd.mm.yyyy) (or type 'stop' to stop): ")
    
    if date_input.lower() == 'stop':
        stop_loop = True
        continue
    
    try:
        week_number = week_calculator(date_input)
    
        annotation_text = input("Enter the annotation text: ")

        # Annotate the user input
        annotate_week(ax, week_number, annotation_text, previous_annotations)
        
        # Display the updated plot
        plt.draw()
    except ValueError:
        print("Please enter a valid date in dd.mm.yyyy format.")

# integer_value = 19.63 # Replace with your desired integer value
# rounded_down = math.floor(integer_value)
# integer_week = ((integer_value - rounded_down) * 52)
# rounded_week = math.ceil(integer_week)

# # Iterate through each row up to the 24th row
# for row in range(int(integer_value) + 1):
#     # Adjust the y-coordinate to draw the line in the middle of each row
#     y_coordinate = row + 0.5
    
#     # If it's the 24th row, draw the line up to column 38
#     if row == rounded_down:
#         ax.hlines(y=y_coordinate, xmin=0, xmax=rounded_week, color='#737373', linewidth=4, linestyle='-')
#     # For other rows, draw the line up to the last column
#     else:
#         ax.hlines(y=y_coordinate, xmin=0, xmax=weeks_per_year, color='#737373', linewidth=4, linestyle='-')

# # Display the plot

# print(rounded_week)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import matplotlib.patches as mpatches
import math
from datetime import datetime
import textwrap

# Define the number of years and weeks per year
years = 90
weeks_per_year = 52

# Create the data and reshape it
data = np.arange(1, years * weeks_per_year + 1).reshape(years, weeks_per_year)

# Create discrete colormap
cmap = colors.ListedColormap([
    "#A5D6A7",  # Early Childhood
    "#FF8A80",  # School Years
    "#FFF59D",  # College
    "#90CAF9",  # Career
    "#CE93D8"   # Retirement
])

# Define the bounds
bounds = [0, 347, 937, 1145, 3121, 5200]
norm = colors.BoundaryNorm(bounds, cmap.N)

fig, ax = plt.subplots(figsize=(20, 12))
extent = [0, weeks_per_year, years, 0]
im = ax.imshow(data, cmap=cmap, norm=norm, aspect='auto', extent=extent)

im.format_cursor_data = lambda data: ""

# Draw gridlines
ax.grid(which='both', axis='both', linestyle='-', color='k', linewidth=0.27)

# Set ticks for weeks on x-axis
ax.set_xticks(np.arange(0, weeks_per_year, 5))
ax.set_xticks(np.arange(0, weeks_per_year + 1, 1), minor=True)

# Set ticks for years on y-axis
ax.set_yticks(np.arange(0, years, 5))
ax.set_yticks(np.arange(0, years + 1, 1), minor=True)

tick_label_size = 12  # Define your desired tick label size here
ax.tick_params(axis='both', which='major', labelsize=tick_label_size)
ax.tick_params(axis='both', which='minor', labelsize=tick_label_size * 0.8)

# Place x-axis labels on top
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Hide the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set labels and title
ax.set_xlabel('Haftalar', fontsize=24, color='#800000')
ax.set_ylabel('Yillar', fontsize=24, color='#800000')
ax.yaxis.set_label_position('left')
ax.yaxis.set_label_coords(-0.05, 0.97)
plt.title('Hayot haftalarda: 90 yil', fontsize=28, color='#191970')

# Create custom legend
legend_patches = [
    mpatches.Patch(color="#A5D6A7", label='Bolalik (0-7 yosh)'),
    mpatches.Patch(color="#FF8A80", label='Maktab yillari (7-18 yosh)'),
    mpatches.Patch(color="#FFF59D", label='Oliy ta\'lim (18-22 yosh)'),
    mpatches.Patch(color="#90CAF9", label='Ish faoliyati (22-60 yosh)'),
    mpatches.Patch(color="#CE93D8", label='Nafaqa davri (60-100 yosh)')
]

# Add the legend to the plot, positioned to the top right and outside the plot
ax.legend(handles=legend_patches, loc='upper left', bbox_to_anchor=(1, 1), fontsize='xx-large')

# Annotate the weeks
def annotate_week(ax, week, text, previous_annotations):
    year = week // weeks_per_year
    week_in_year = week % weeks_per_year

    # Calculate the center of the box for the given week
    center_x = week_in_year + 0.5
    center_y = year + 0.5

    # Wrap text if it's too long
    wrapped_text = "\n".join(textwrap.wrap(text, width=30))

    # Calculate the offset for the annotation text to avoid overlap
    offset = 0
    for prev_center_y, prev_text in previous_annotations:
        if abs(prev_center_y - center_y) < 5:  # If the y position is very close to previous
            offset += 20  # Adjust the offset as needed to avoid overlap

    xytext = (-17, center_y + offset)

    # Create the main annotation box with the updated placement
    ax.annotate(
        wrapped_text, 
        xy=(center_x, center_y), 
        xytext=xytext,  # Adjusted xytext coordinates
        textcoords='data',
        va='center', ha='left',
        bbox=dict(boxstyle='round', facecolor='white', edgecolor='black'),
        fontsize=14,
        arrowprops=dict(arrowstyle='-|>', edgecolor='black', facecolor='black', shrinkA=0, shrinkB=5, connectionstyle="arc3, rad=0.1"),
        annotation_clip=False
    )

    # Append the current center_y and text length to the list of previous annotations
    previous_annotations.append((center_y + offset, wrapped_text))

def week_calculator(birthday, date_str):
    birth_date = datetime.strptime(birthday, "%d.%m.%Y")
    target_date = datetime.strptime(date_str, "%d.%m.%Y")
    delta = target_date - birth_date
    return delta.days // 7  # Convert days to weeks

# Main function
def main():
    # Get user's birthday
    birthday_input = input("Enter your birthday (dd.mm.yyyy): ")
    
    # Validate birthday input
    try:
        datetime.strptime(birthday_input, "%d.%m.%Y")
    except ValueError:
        print("Please enter a valid date in dd.mm.yyyy format.")
        return

    previous_annotations = []

    stop_loop = False
    while not stop_loop:
        date_input = input("Enter an important date (dd.mm.yyyy) (or type 'stop' to stop): ")
        
        if date_input.lower() == 'stop':
            stop_loop = True
            continue
        
        try:
            week_number = week_calculator(birthday_input, date_input)
            annotation_text = input("Enter the annotation text: ")

            # Annotate the user input
            annotate_week(ax, week_number, annotation_text, previous_annotations)
            
            # Display the updated plot
            plt.draw()
        except ValueError:
            print("Please enter a valid date in dd.mm.yyyy format.")

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import matplotlib.patches as mpatches
import math
from datetime import datetime
import textwrap

# Define the number of years and weeks per year
years = 90
weeks_per_year = 52

# Create the data and reshape it
data = np.arange(1, years * weeks_per_year + 1).reshape(years, weeks_per_year)

# Create discrete colormap
cmap = colors.ListedColormap([
    "#A5D6A7",  # Early Childhood
    "#FF8A80",  # School Years
    "#FFF59D",  # College
    "#90CAF9",  # Career
    "#CE93D8"   # Retirement
])

# Define the bounds
bounds = [0, 347, 937, 1145, 3121, 5200]
norm = colors.BoundaryNorm(bounds, cmap.N)

fig, ax = plt.subplots(figsize=(20, 12))
extent = [0, weeks_per_year, years, 0]
im = ax.imshow(data, cmap=cmap, norm=norm, aspect='auto', extent=extent)

im.format_cursor_data = lambda data: ""

# Draw gridlines
ax.grid(which='both', axis='both', linestyle='-', color='k', linewidth=0.27)

# Set ticks for weeks on x-axis
ax.set_xticks(np.arange(0, weeks_per_year, 5))
ax.set_xticks(np.arange(0, weeks_per_year + 1, 1), minor=True)

# Set ticks for years on y-axis
ax.set_yticks(np.arange(0, years, 5))
ax.set_yticks(np.arange(0, years + 1, 1), minor=True)

tick_label_size = 12  # Define your desired tick label size here
ax.tick_params(axis='both', which='major', labelsize=tick_label_size)
ax.tick_params(axis='both', which='minor', labelsize=tick_label_size * 0.8)

# Place x-axis labels on top
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Hide the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set labels and title
ax.set_xlabel('Haftalar', fontsize=24, color='#800000')
ax.set_ylabel('Yillar', fontsize=24, color='#800000')
ax.yaxis.set_label_position('left')
ax.yaxis.set_label_coords(-0.05, 0.97)
plt.title('Hayot haftalarda: 90 yil', fontsize=28, color='#191970')

# Create custom legend
legend_patches = [
    mpatches.Patch(color="#A5D6A7", label='Bolalik (0-7 yosh)'),
    mpatches.Patch(color="#FF8A80", label='Maktab yillari (7-18 yosh)'),
    mpatches.Patch(color="#FFF59D", label='Oliy ta\'lim (18-22 yosh)'),
    mpatches.Patch(color="#90CAF9", label='Ish faoliyati (22-60 yosh)'),
    mpatches.Patch(color="#CE93D8", label='Nafaqa davri (60-100 yosh)')
]

# Add the legend to the plot, positioned to the top right and outside the plot
ax.legend(handles=legend_patches, loc='upper left', bbox_to_anchor=(1, 1), fontsize='xx-large')

# Annotate the weeks
def annotate_week(ax, week, text, previous_annotations):
    year = week // weeks_per_year
    week_in_year = week % weeks_per_year

    # Calculate the center of the box for the given week
    center_x = week_in_year + 0.5
    center_y = year + 0.5

    # Wrap text if it's too long
    wrapped_text = "\n".join(textwrap.wrap(text, width=30))

    # Calculate the offset for the annotation text to avoid overlap
    offset = 0
    for prev_center_y, prev_text in previous_annotations:
        if abs(prev_center_y - center_y) < 5:  # If the y position is very close to previous
            offset += 20  # Adjust the offset as needed to avoid overlap

    xytext = (-17, center_y + offset)

    # Create the main annotation box with the updated placement
    ax.annotate(
        wrapped_text, 
        xy=(center_x, center_y), 
        xytext=xytext,  # Adjusted xytext coordinates
        textcoords='data',
        va='center', ha='left',
        bbox=dict(boxstyle='round', facecolor='white', edgecolor='black'),
        fontsize=14,
        arrowprops=dict(arrowstyle='-|>', edgecolor='black', facecolor='black', shrinkA=0, shrinkB=5, connectionstyle="arc3, rad=0.1"),
        annotation_clip=False
    )

    # Append the current center_y and text length to the list of previous annotations
    previous_annotations.append((center_y + offset, wrapped_text))

def week_calculator(birthday, date_str):
    birth_date = datetime.strptime(birthday, "%d.%m.%Y")
    target_date = datetime.strptime(date_str, "%d.%m.%Y")
    delta = target_date - birth_date
    return delta.days // 7  # Convert days to weeks

def weeks_from_birthday_to_today(birthday):
    birth_date = datetime.strptime(birthday, "%d.%m.%Y")
    today = datetime.today()
    delta = today - birth_date
    return delta.days // 7  # Convert days to weeks

def draw_life_line(ax, birthday):
    weeks_to_today = weeks_from_birthday_to_today(birthday)
    current_year = weeks_to_today // weeks_per_year
    current_week_in_year = weeks_to_today % weeks_per_year

    for row in range(current_year + 1):
        if row == current_year:
            ax.hlines(y=row + 0.5, xmin=0, xmax=current_week_in_year, color='black', linewidth=2, linestyle='-')
        else:
            ax.hlines(y=row + 0.5, xmin=0, xmax=weeks_per_year, color='black', linewidth=2, linestyle='-')

# Main function
def main():
    # Get user's birthday
    birthday_input = input("Enter your birthday (dd.mm.yyyy): ")
    
    # Validate birthday input
    try:
        datetime.strptime(birthday_input, "%d.%m.%Y")
    except ValueError:
        print("Please enter a valid date in dd.mm.yyyy format.")
        return

    # Draw life line from birthday to today
    draw_life_line(ax, birthday_input)

    previous_annotations = []

    stop_loop = False
    while not stop_loop:
        date_input = input("Enter an important date (dd.mm.yyyy) (or type 'stop' to stop): ")
        
        if date_input.lower() == 'stop':
            stop_loop = True
            continue
        
        try:
            week_number = week_calculator(birthday_input, date_input)
            annotation_text = input("Enter the annotation text: ")

            # Annotate the user input
            annotate_week(ax, week_number, annotation_text, previous_annotations)
            
            # Display the updated plot
            plt.draw()
        except ValueError:
            print("Please enter a valid date in dd.mm.yyyy format.")

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.patches as mpatches
import random
from datetime import datetime
import textwrap

# Define the number of years and weeks per year
years = 90
weeks_per_year = 52

# Create the data and reshape it
data = np.arange(1, years * weeks_per_year + 1).reshape(years, weeks_per_year)

# Create plain white grid
fig, ax = plt.subplots(figsize=(20, 12))
extent = [0, weeks_per_year, years, 0]
im = ax.imshow(data, cmap="gray", aspect='auto', extent=extent, vmin=0, vmax=1)

im.format_cursor_data = lambda data: ""

# Draw gridlines
ax.grid(which='both', axis='both', linestyle='-', color='k', linewidth=0.27)

# Set ticks for weeks on x-axis
ax.set_xticks(np.arange(0, weeks_per_year, 5))
ax.set_xticks(np.arange(0, weeks_per_year + 1, 1), minor=True)

# Set ticks for years on y-axis
ax.set_yticks(np.arange(0, years, 5))
ax.set_yticks(np.arange(0, years + 1, 1), minor=True)

tick_label_size = 12  # Define your desired tick label size here
ax.tick_params(axis='both', which='major', labelsize=tick_label_size)
ax.tick_params(axis='both', which='minor', labelsize=tick_label_size * 0.8)

# Place x-axis labels on top
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Hide the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set labels and title
ax.set_xlabel('Haftalar', fontsize=24, color='#800000')
ax.set_ylabel('Yillar', fontsize=24, color='#800000')
ax.yaxis.set_label_position('left')
ax.yaxis.set_label_coords(-0.05, 0.97)
plt.title('Hayot haftalarda: 90 yil', fontsize=28, color='#191970')

# Annotate the weeks
def annotate_week(ax, week, text, previous_annotations):
    year = week // weeks_per_year
    week_in_year = week % weeks_per_year

    # Calculate the center of the box for the given week
    center_x = week_in_year + 0.5
    center_y = year + 0.5

    # Wrap text if it's too long
    wrapped_text = "\n".join(textwrap.wrap(text, width=30))

    # Calculate the offset for the annotation text to avoid overlap
    offset = 0
    for prev_center_y, prev_text in previous_annotations:
        if abs(prev_center_y - center_y) < 5:  # If the y position is very close to previous
            offset += 20  # Adjust the offset as needed to avoid overlap

    xytext = (-17, center_y + offset)

    # Choose a random color for the annotation
    colors = ['darkred', 'darkblue', 'green']
    color = random.choice(colors)

    # Create the main annotation box with the updated placement
    ax.annotate(
        wrapped_text, 
        xy=(center_x, center_y), 
        xytext=xytext,  # Adjusted xytext coordinates
        textcoords='data',
        va='center', ha='left',
        bbox=dict(boxstyle='round', facecolor='white', edgecolor=color),
        fontsize=14,
        color=color,  # Set the text color
        arrowprops=dict(arrowstyle='-|>', edgecolor=color, facecolor=color, shrinkA=0, shrinkB=5, connectionstyle="arc3, rad=0.1"),
        annotation_clip=False
    )

    # Append the current center_y and text length to the list of previous annotations
    previous_annotations.append((center_y + offset, wrapped_text))

def week_calculator(birthday, date_str):
    birth_date = datetime.strptime(birthday, "%d.%m.%Y")
    target_date = datetime.strptime(date_str, "%d.%m.%Y")
    delta = target_date - birth_date
    return delta.days // 7  # Convert days to weeks

def main():
    previous_annotations = []

    while True:
        # Get famous person's birthday
        birthday_input = input("Enter the birthday of a famous person (dd.mm.yyyy) or type 'stop' to finish: ")
        
        if birthday_input.lower() == 'stop':
            break

        # Validate birthday input
        try:
            datetime.strptime(birthday_input, "%d.%m.%Y")
        except ValueError:
            print("Please enter a valid date in dd.mm.yyyy format.")
            continue

        date_input = input("Enter an important date in their life (dd.mm.yyyy): ")
        try:
            week_number = week_calculator(birthday_input, date_input)
            annotation_text = input("Enter the annotation text: ")

            # Annotate the user input
            annotate_week(ax, week_number, annotation_text, previous_annotations)
            
            # Display the updated plot
            plt.draw()
        except ValueError:
            print("Please enter a valid date in dd.mm.yyyy format.")

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import matplotlib.patches as mpatches
import math
from datetime import datetime
import textwrap

# Define the number of years and weeks per year
years = 90
weeks_per_year = 52

# Create the data and reshape it
data = np.arange(1, years * weeks_per_year + 1).reshape(years, weeks_per_year)

# Create discrete colormap
cmap = colors.ListedColormap([
    "#A5D6A7",  # Early Childhood
    "#FF8A80",  # School Years
    "#FFF59D",  # College
    "#90CAF9",  # Career
    "#CE93D8"   # Retirement
])

# Define the bounds
bounds = [0, 347, 937, 1145, 3121, 5200]
norm = colors.BoundaryNorm(bounds, cmap.N)

fig, ax = plt.subplots(figsize=(20, 12))
extent = [0, weeks_per_year, years, 0]
im = ax.imshow(data, cmap=cmap, norm=norm, aspect='auto', extent=extent)

im.format_cursor_data = lambda data: ""

# Draw gridlines
ax.grid(which='both', axis='both', linestyle='-', color='k', linewidth=0.27)

# Set ticks for weeks on x-axis
ax.set_xticks(np.arange(0, weeks_per_year, 5))
ax.set_xticks(np.arange(0, weeks_per_year + 1, 1), minor=True)

# Set ticks for years on y-axis
ax.set_yticks(np.arange(0, years, 5))
ax.set_yticks(np.arange(0, years + 1, 1), minor=True)

tick_label_size = 12  # Define your desired tick label size here
ax.tick_params(axis='both', which='major', labelsize=tick_label_size)
ax.tick_params(axis='both', which='minor', labelsize=tick_label_size * 0.8)

# Place x-axis labels on top
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Hide the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set labels and title
ax.set_xlabel('Haftalar', fontsize=24, color='#800000')
ax.set_ylabel('Yillar', fontsize=24, color='#800000')
ax.yaxis.set_label_position('left')
ax.yaxis.set_label_coords(-0.05, 0.97)
plt.title('Hayot haftalarda: 90 yil', fontsize=28, color='#191970')

# Create custom legend
legend_patches = [
    mpatches.Patch(color="#A5D6A7", label='Bolalik (0-7 yosh)'),
    mpatches.Patch(color="#FF8A80", label='Maktab yillari (7-18 yosh)'),
    mpatches.Patch(color="#FFF59D", label='Oliy ta\'lim (18-22 yosh)'),
    mpatches.Patch(color="#90CAF9", label='Ish faoliyati (22-60 yosh)'),
    mpatches.Patch(color="#CE93D8", label='Nafaqa davri (60-100 yosh)')
]

# Add the legend to the plot, positioned to the top right and outside the plot
ax.legend(handles=legend_patches, loc='upper left', bbox_to_anchor=(1, 1), fontsize='xx-large')

# Annotate the weeks
def annotate_week(ax, week, text, previous_annotations, right_annotations_y):
    year = week // weeks_per_year
    week_in_year = week % weeks_per_year

    # Calculate the center of the box for the given week
    center_x = week_in_year + 0.5
    center_y = year + 0.5

    # Wrap text if it's too long
    wrapped_text = "\n".join(textwrap.wrap(text, width=30))

    # Determine the x and y offset based on position to avoid overlap
    if week_in_year <= 26:
        x_offset = -60
        ha = 'right'
        xytext = (center_x + x_offset, center_y)
    else:
        x_offset = 60  # Adjust for outside the grid
        ha = 'left'
        # Maintain the same y position for the arrow but offset the text box vertically
        if right_annotations_y:
            center_y_text = right_annotations_y.pop(0)  # Adjust y position for right-side annotations
        else:
            center_y_text = center_y

        xytext = (center_x + x_offset, center_y_text)

    # Create the main annotation box with the updated placement
    ax.annotate(
        wrapped_text,
        xy=(center_x, center_y),
        xytext=xytext,
        textcoords='data',
        va='center', ha=ha,
        bbox=dict(boxstyle='round', facecolor='white', edgecolor='black'),
        fontsize=14,
        arrowprops=dict(arrowstyle='-|>', edgecolor='black', facecolor='black', shrinkA=0, shrinkB=5, connectionstyle="arc3,rad=0.1"),
        annotation_clip=False
    )

    # Append the current center_y and text length to the list of previous annotations
    previous_annotations.append((center_y_text, wrapped_text))

def week_calculator(birthday, date_str):
    birth_date = datetime.strptime(birthday, "%d.%m.%Y")
    target_date = datetime.strptime(date_str, "%d.%m.%Y")
    delta = target_date - birth_date
    return delta.days // 7  # Convert days to weeks

def weeks_from_birthday_to_today(birthday):
    birth_date = datetime.strptime(birthday, "%d.%m.%Y")
    today = datetime.today()
    delta = today - birth_date
    return delta.days // 7  # Convert days to weeks

def draw_life_line(ax, birthday):
    weeks_to_today = weeks_from_birthday_to_today(birthday)
    current_year = weeks_to_today // weeks_per_year
    current_week_in_year = weeks_to_today % weeks_per_year

    for row in range(current_year + 1):
        if row == current_year:
            ax.hlines(y=row + 0.5, xmin=0, xmax=current_week_in_year, color='black', linewidth=2, linestyle='-')
        else:
            ax.hlines(y=row + 0.5, xmin=0, xmax=weeks_per_year, color='black', linewidth=2, linestyle='-')

# Main function
def main():
    # Get user's birthday
    birthday_input = input("Enter your birthday (dd.mm.yyyy): ")
    
    # Validate birthday input
    try:
        datetime.strptime(birthday_input, "%d.%m.%Y")
    except ValueError:
        print("Please enter a valid date in dd.mm.yyyy format.")
        return

    # Draw life line from birthday to today
    draw_life_line(ax, birthday_input)

    previous_annotations = []
    right_annotations_y = list(range(10, 90, 10))  # Adjust the range and step as needed

    stop_loop = False
    while not stop_loop:
        date_input = input("Enter an important date (dd.mm.yyyy) (or type 'stop' to stop): ")
        
        if date_input.lower() == 'stop':
            stop_loop = True
            continue
        
        try:
            week_number = week_calculator(birthday_input, date_input)
            annotation_text = input("Enter the annotation text: ")

            # Annotate the user input
            annotate_week(ax, week_number, annotation_text, previous_annotations, right_annotations_y)
            
            # Display the updated plot
            plt.draw()
        except ValueError:
            print("Please enter a valid date in dd.mm.yyyy format.")

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import matplotlib.patches as mpatches
import math
from datetime import datetime
import textwrap

# Define the number of years and weeks per year
years = 90
weeks_per_year = 52

# Create the data and reshape it
data = np.arange(1, years * weeks_per_year + 1).reshape(years, weeks_per_year)

# Create discrete colormap
cmap = colors.ListedColormap([
    "#A5D6A7",  # Early Childhood
    "#FF8A80",  # School Years
    "#FFF59D",  # College
    "#90CAF9",  # Career
    "#CE93D8"   # Retirement
])

# Define the bounds
bounds = [0, 347, 937, 1145, 3121, 5200]
norm = colors.BoundaryNorm(bounds, cmap.N)

fig, ax = plt.subplots(figsize=(20, 12))
extent = [0, weeks_per_year, years, 0]
im = ax.imshow(data, cmap=cmap, norm=norm, aspect='auto', extent=extent)

im.format_cursor_data = lambda data: ""

# Draw gridlines
ax.grid(which='both', axis='both', linestyle='-', color='k', linewidth=0.27)

# Set ticks for weeks on x-axis
ax.set_xticks(np.arange(0, weeks_per_year, 5))
ax.set_xticks(np.arange(0, weeks_per_year + 1, 1), minor=True)

# Set ticks for years on y-axis
ax.set_yticks(np.arange(0, years, 5))
ax.set_yticks(np.arange(0, years + 1, 1), minor=True)

tick_label_size = 12  # Define your desired tick label size here
ax.tick_params(axis='both', which='major', labelsize=tick_label_size)
ax.tick_params(axis='both', which='minor', labelsize=tick_label_size * 0.8)

# Place x-axis labels on top
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Hide the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set labels and title
ax.set_xlabel('Haftalar', fontsize=24, color='#800000')
ax.set_ylabel('Yillar', fontsize=24, color='#800000')
ax.yaxis.set_label_position('left')
ax.yaxis.set_label_coords(-0.05, 0.97)
plt.title('Hayot haftalarda: 90 yil', fontsize=28, color='#191970')

# Create custom legend
legend_patches = [
    mpatches.Patch(color="#A5D6A7", label='Bolalik (0-7 yosh)'),
    mpatches.Patch(color="#FF8A80", label='Maktab yillari (7-18 yosh)'),
    mpatches.Patch(color="#FFF59D", label='Oliy ta\'lim (18-22 yosh)'),
    mpatches.Patch(color="#90CAF9", label='Ish faoliyati (22-60 yosh)'),
    mpatches.Patch(color="#CE93D8", label='Nafaqa davri (60-100 yosh)')
]

# Add the legend to the plot, positioned to the top right and outside the plot
ax.legend(handles=legend_patches, loc='upper left', bbox_to_anchor=(1, 1), fontsize='xx-large')

# Annotate the weeks
def annotate_week(ax, week, text, previous_annotations, right_annotations_y):
    year = week // weeks_per_year
    week_in_year = week % weeks_per_year

    # Calculate the center of the box for the given week
    center_x = week_in_year + 0.5
    center_y = year + 0.5

    # Wrap text if it's too long
    wrapped_text = "\n".join(textwrap.wrap(text, width=30))

    # Determine the x and y offset based on position to avoid overlap
    if week_in_year <= 26:
        x_offset = -60
        ha = 'right'
        xytext = (center_x + x_offset, center_y)
    else:
        x_offset = 60  # Adjust for outside the grid
        ha = 'left'
        # Maintain the same y position for the arrow but offset the text box vertically
        if right_annotations_y:
            center_y_text = right_annotations_y.pop(0)  # Adjust y position for right-side annotations
        else:
            center_y_text = center_y

        xytext = (center_x + x_offset, center_y_text)

    # Create the main annotation box with the updated placement
    ax.annotate(
        wrapped_text,
        xy=(center_x, center_y),
        xytext=xytext,
        textcoords='data',
        va='center', ha=ha,
        bbox=dict(boxstyle='round', facecolor='white', edgecolor='black'),
        fontsize=14,
        arrowprops=dict(arrowstyle='-|>', edgecolor='black', facecolor='black', shrinkA=0, shrinkB=5, connectionstyle="arc3,rad=0.1"),
        annotation_clip=False
    )

    # Append the current center_y and text length to the list of previous annotations
    previous_annotations.append((center_y_text, wrapped_text))

def week_calculator(birthday, date_str):
    birth_date = datetime.strptime(birthday, "%d.%m.%Y")
    target_date = datetime.strptime(date_str, "%d.%m.%Y")
    delta = target_date - birth_date
    return delta.days // 7  # Convert days to weeks

def weeks_from_birthday_to_today(birthday):
    birth_date = datetime.strptime(birthday, "%d.%m.%Y")
    today = datetime.today()
    delta = today - birth_date
    return delta.days // 7  # Convert days to weeks

def draw_life_line(ax, birthday):
    weeks_to_today = weeks_from_birthday_to_today(birthday)
    current_year = weeks_to_today // weeks_per_year
    current_week_in_year = weeks_to_today % weeks_per_year

    for row in range(current_year + 1):
        if row == current_year:
            ax.hlines(y=row + 0.5, xmin=0, xmax=current_week_in_year, color='black', linewidth=2, linestyle='-')
        else:
            ax.hlines(y=row + 0.5, xmin=0, xmax=weeks_per_year, color='black', linewidth=2, linestyle='-')

# Main function
def main():
    # Get user's birthday
    birthday_input = input("Enter your birthday (dd.mm.yyyy): ")
    
    # Validate birthday input
    try:
        datetime.strptime(birthday_input, "%d.%m.%Y")
    except ValueError:
        print("Please enter a valid date in dd.mm.yyyy format.")
        return

    # Draw life line from birthday to today
    draw_life_line(ax, birthday_input)

    previous_annotations = []
    right_annotations_y = list(range(35, 90, 10))  # Adjust the range and step to start below the legend

    stop_loop = False
    while not stop_loop:
        date_input = input("Enter an important date (dd.mm.yyyy) (or type 'stop' to stop): ")
        
        if date_input.lower() == 'stop':
            stop_loop = True
            continue
        
        try:
            week_number = week_calculator(birthday_input, date_input)
            annotation_text = input("Enter the annotation text: ")

            # Annotate the user input
            annotate_week(ax, week_number, annotation_text, previous_annotations, right_annotations_y)
            
            # Display the updated plot
            plt.draw()
        except ValueError:
            print("Please enter a valid date in dd.mm.yyyy format.")

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_19161/4011205575.py in <module>
#     184
#     185 if __name__ == "__main__":
# --> 186     main()
#
# /tmp/ipykernel_19161/4011205575.py in main()
#     173
#     174             # Annotate the user input
# --> 175             annotate_week(ax, week_number, annotation_text, previous_annotations, right_annotations_y)
#     176
#     177             # Display the updated plot
#
# /tmp/ipykernel_19161/4011205575.py in annotate_week(ax, week, text, previous_annotations, right_annotations_y)
#     117
#     118     # Append the current center_y and text length to the list of previous annotations
# --> 119     previous_annotations.append((center_y_text, wrapped_text))
#     120
#     121 def week_calculator(birthday, date_str):
#
# UnboundLocalError: local variable 'center_y_text' referenced before assignment

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np
import matplotlib.patches as mpatches
import textwrap
from datetime import datetime

# Define the number of years and weeks per year
years = 90
weeks_per_year = 52

# Create the data and reshape it
data = np.arange(1, years * weeks_per_year + 1).reshape(years, weeks_per_year)

# Create discrete colormap
cmap = colors.ListedColormap([
    "#A5D6A7",  # Early Childhood
    "#FF8A80",  # School Years
    "#FFF59D",  # College
    "#90CAF9",  # Career
    "#CE93D8"   # Retirement
])

# Define the bounds
bounds = [0, 347, 937, 1145, 3121, 5200]
norm = colors.BoundaryNorm(bounds, cmap.N)

fig, ax = plt.subplots(figsize=(20, 12))
extent = [0, weeks_per_year, years, 0]
im = ax.imshow(data, cmap=cmap, norm=norm, aspect='auto', extent=extent)

im.format_cursor_data = lambda data: ""

# Draw gridlines
ax.grid(which='both', axis='both', linestyle='-', color='k', linewidth=0.27)

# Set ticks for weeks on x-axis
ax.set_xticks(np.arange(0, weeks_per_year, 5))
ax.set_xticks(np.arange(0, weeks_per_year + 1, 1), minor=True)

# Set ticks for years on y-axis
ax.set_yticks(np.arange(0, years, 5))
ax.set_yticks(np.arange(0, years + 1, 1), minor=True)

tick_label_size = 12  # Define your desired tick label size here
ax.tick_params(axis='both', which='major', labelsize=tick_label_size)
ax.tick_params(axis='both', which='minor', labelsize=tick_label_size * 0.8)

# Place x-axis labels on top
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_label_position('top')

# Hide the top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Set labels and title
ax.set_xlabel('Haftalar', fontsize=24, color='#800000')
ax.set_ylabel('Yillar', fontsize=24, color='#800000')
ax.yaxis.set_label_position('left')
ax.yaxis.set_label_coords(-0.05, 0.97)
plt.title('Hayot haftalarda: 90 yil', fontsize=28, color='#191970')

# Create custom legend
legend_patches = [
    mpatches.Patch(color="#A5D6A7", label='Bolalik (0-7 yosh)'),
    mpatches.Patch(color="#FF8A80", label='Maktab yillari (7-18 yosh)'),
    mpatches.Patch(color="#FFF59D", label='Oliy ta\'lim (18-22 yosh)'),
    mpatches.Patch(color="#90CAF9", label='Ish faoliyati (22-60 yosh)'),
    mpatches.Patch(color="#CE93D8", label='Nafaqa davri (60-100 yosh)')
]

# Add the legend to the plot, positioned to the top right and outside the plot
ax.legend(handles=legend_patches, loc='upper left', bbox_to_anchor=(1, 1), fontsize='xx-large')

# Annotate the weeks
def annotate_week(ax, week, text, previous_annotations, right_annotations_y):
    year = week // weeks_per_year
    week_in_year = week % weeks_per_year

    # Calculate the center of the box for the given week
    center_x = week_in_year + 0.5
    center_y = year + 0.5

    # Wrap text if it's too long
    wrapped_text = "\n".join(textwrap.wrap(text, width=30))

    # Determine the x and y offset based on position to avoid overlap
    if week_in_year <= 26:
        x_offset = -30
        ha = 'right'
        xytext = (center_x + x_offset, center_y)
    else:
        x_offset = 30  # Adjust for outside the grid
        ha = 'left'
        if right_annotations_y:
            center_y_text = right_annotations_y.pop(0)  # Adjust y position for right-side annotations
        else:
            center_y_text = center_y

        xytext = (center_x + x_offset, center_y_text)

    # Create the main annotation box with the updated placement
    ax.annotate(
        wrapped_text,
        xy=(center_x, center_y),
        xytext=xytext,
        textcoords='data',
        va='center', ha=ha,
        bbox=dict(boxstyle='round', facecolor='white', edgecolor='black'),
        fontsize=14,
        arrowprops=dict(arrowstyle='-|>', edgecolor='black', facecolor='black', shrinkA=0, shrinkB=5, connectionstyle="arc3,rad=0.1"),
        annotation_clip=False
    )

    # Append the current center_y and text length to the list of previous annotations
    previous_annotations.append((center_y, wrapped_text))

def week_calculator(birthday, date_str):
    birth_date = datetime.strptime(birthday, "%d.%m.%Y")
    target_date = datetime.strptime(date_str, "%d.%m.%Y")
    delta = target_date - birth_date
    return delta.days // 7  # Convert days to weeks

def weeks_from_birthday_to_today(birthday):
    birth_date = datetime.strptime(birthday, "%d.%m.%Y")
    today = datetime.today()
    delta = today - birth_date
    return delta.days // 7  # Convert days to weeks

def draw_life_line(ax, birthday):
    weeks_to_today = weeks_from_birthday_to_today(birthday)
    current_year = weeks_to_today // weeks_per_year
    current_week_in_year = weeks_to_today % weeks_per_year

    for row in range(current_year + 1):
        if row == current_year:
            ax.hlines(y=row + 0.5, xmin=0, xmax=current_week_in_year, color='black', linewidth=2, linestyle='-')
        else:
            ax.hlines(y=row + 0.5, xmin=0, xmax=weeks_per_year, color='black', linewidth=2, linestyle='-')

# Main function
def main():
    # Get user's birthday
    birthday_input = input("Enter your birthday (dd.mm.yyyy): ")
    
    # Validate birthday input
    try:
        datetime.strptime(birthday_input, "%d.%m.%Y")
    except ValueError:
        print("Please enter a valid date in dd.mm.yyyy format.")
        return

    # Draw life line from birthday to today
    draw_life_line(ax, birthday_input)

    previous_annotations = []
    right_annotations_y = list(range(35, 90, 10))  # Adjust the range and step to start below the legend

    stop_loop = False
    while not stop_loop:
        date_input = input("Enter an important date (dd.mm.yyyy) (or type 'stop' to stop): ")
        
        if date_input.lower() == 'stop':
            stop_loop = True
            continue
        
        try:
            week_number = week_calculator(birthday_input, date_input)
            annotation_text = input("Enter the annotation text: ")

            # Annotate the user input
            annotate_week(ax, week_number, annotation_text, previous_annotations, right_annotations_y)
            
            # Display the updated plot
            plt.draw()
        except ValueError:
            print("Please enter a valid date in dd.mm.yyyy format.")

    plt.tight_layout()
    plt.show()

if __name__ == "__main__":
    main()
